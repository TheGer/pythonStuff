# %% [markdown]
# <b>Worksheet 6</b>
#
# Task 1 - Plotting grayscale image histogram:

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

myimage = cv2.imread('../images/lena.jpg')

fig,axs = plt.subplots(1,2)
fig.set_dpi(300)
grayimage = cv2.cvtColor(myimage, cv2.COLOR_BGR2GRAY)
axs[0].imshow(grayimage, cmap=plt.cm.gray)
axs[1].hist(grayimage.ravel(),256,[0,256]);
plt.show()

# %% [markdown]
# Worksheet 6 - Task 2

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

img = cv2.imread('../images/black_dots.bmp')
dots_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


height, width = dots_img.shape
print(height, width)
count = 0

for x in range(height):
    for y in range(width):
        if dots_img[x,y] == 0:
            count+=1
            cv2.circle(img, center=(y,x), radius=10, color=(255,0,0), thickness=3)
label = 'No of pixels: ' + str(count)
cv2.putText(img, label, (10,30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2)
plt.imshow(img)
plt.show()
print(count)
# Out:
# 602 917
# 6

# %% [markdown]
# Worksheet 6 Task 3:

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2

x = np.random.randint(100)

myarray = np.zeros([15, 15, 3], dtype=np.uint8)
myarray = np.random.randint(2, size=(15, 15, 3), dtype=np.uint8)
myarray= myarray * 255


height, width, channels = myarray.shape
print(height, width)

#img = myarray
#img = np.zeros((150,150), dtype=np.uint8)
img = cv2.resize(myarray, (150,150), interpolation = cv2.INTER_AREA)

redcount, greencount, bluecount = 0, 0, 0

for x in range(width):
    for y in range(height):
        if (myarray[y,x,0] == 255) and (myarray[y,x,1] == 0) and (myarray[y,x,2] == 0):
            cv2.circle(img, ((x*10)+4,(y*10)+4), 7, (255,0,0), 1)
            redcount+=1
        if (myarray[y,x,0] == 0) and (myarray[y,x,1] == 255) and (myarray[y,x,2] == 0):
            cv2.circle(img, ((x*10)+4,(y*10)+4), 7, (0,255,0), 1)
            greencount+=1
        if (myarray[y,x,0] == 0) and (myarray[y,x,1] == 0) and (myarray[y,x,2] == 255):
            cv2.circle(img, ((x*10)+4,(y*10)+4), 7, (0,0,255), 1)
            bluecount+=1

print(redcount, greencount, bluecount)
#img = Image.fromarray(myarray)

plt.imshow(img)
plt.show()
# Out:
# 15 15
# 35 21 27
